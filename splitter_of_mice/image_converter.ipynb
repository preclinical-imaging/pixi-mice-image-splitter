# %%
'''
Notebook: image converter.ipynb
Authors: Mikhail Milchenko (animal detection), Jack Muskopf (microPET image i/o)
Description: split microPET mice images into individual animal images (separate algorithms for PET and CT)

Copyright 2017-2019
Washington University, Mallinckrodt Insitute of Radiology. All rights reserved. 
This software may not be reproduced, copied, or distributed without written permission of Washington University. 
For more information contact Mikhail Milchenko, PhD
'''
# Out:
# '\nNotebook: image converter.ipynb\nAuthors: Mikhail Milchenko (animal detection), Jack Muskopf (microPET image i/o)\nDescription: split microPET mice images into individual animal images (separate algorithms for PET and CT)\n\nCopyright 2017-2019\nWashington University, Mallinckrodt Insitute of Radiology. All rights reserved. \nThis software may not be reproduced, copied, or distributed without written permission of Washington University. \nFor more information contact Mikhail Milchenko, PhD\n'

# %%
import os
import sys
import numpy as np
import ntpath
import warnings
import tempfile
import struct
import copy
import gc
import shutil

#comment out the next line if running outside of Jupyter notebooks.
import ipywidgets as ipw

from PIL import Image, ImageDraw
from io import BytesIO
import inspect
import nibabel
import skimage
from skimage import measure, filters, morphology

class Params:
    def __init__(self,**kwargs):
        self.__dict__.update(kwargs)

class BaseImage:
    def __init__(self, filepath=None, img_data=None, frame_range=None):
        self.filepath = filepath
        self.img_data = img_data
        self.ax_map = {'z':0,'y':1,'x':2}
        self.inv_ax_map = {v:k for k,v in self.ax_map.items()}
        self.struct_flags = {
                                1:'B',
                                2:'h',
                                3:'i',
                                4:'f'
                            }
        self.frame_range = frame_range
        if filepath is not None:
            self.filename = ntpath.basename(filepath)
            fpcs = self.filename.split('_')
            if len(fpcs) >= 4:
                self.subject_id = fpcs[0] + fpcs[3].split('.')[0]
            else:
                self.subject_id = fpcs[0]
        self.cuts = []
        self.scale_factor = None
        self.scaled = None
        self.bpp = None # bytes per pixel
        self.tempdir = None
        self.data_lim = 10**7  # 10 MB
        self.rotation_history = []

        # color map for distinguishing cuts
        self.all_colors = [
            'red',
            'green',
            'blue',
            'orange',
            'magenta',
            'cyan'
        ]
        self.colors = [x for x in self.all_colors]


    def center_on_zeros(self, mat, xdim, ydim):
        if len(mat.shape) != 2:
            raise ValueError('Wrong shape matrix in center_on_zeros')
        mx,my = mat.shape
        if mx > xdim or my > ydim:
            raise ValueError('Cannot place {}x{} matrix on {}x{} matrix'.format(mx,my,xdim,ydim))
        fillmat = np.zeros((xdim,ydim))

        # find centers
        ccx,ccy = (round(mx/2),round(my/2))
        czx,czy = (round(xdim/2),round(ydim/2))

        # find indices
        sx = czx - ccx
        ex = mx + sx
        sy = czy - ccy
        ey = my + sy

        fillmat[sx:ex,sy:ey] = mat

        return fillmat


    def submemmap(self, ix, data):
        if self.tempdir is None:
            raise ValueError('self.tempdir is None in self.sub_memmap.')

        
        found_filename = False
        while not found_filename:
            fnpcs = self.filename.split('.')
            fnpcs[0] = fnpcs[0] + '_s{}'.format(ix)
            filename = '.'.join(fnpcs)
            img_temp_name = os.path.join(self.tempdir,'{}.dat'.format(filename.split('.')[0]))
            found_filename = not os.path.exists(img_temp_name)
            ix+=1

        dfile = np.memmap(img_temp_name, mode='w+', dtype='float32', shape=self.img_data.shape)

        # center cut on parent image dimensions
        dz,dy,dx,df = data.shape
        print('dz,dy,dx,df',dz,dy,dx,df)
        xdim = self.params.x_dimension
        ydim = self.params.y_dimension
        print('xdim,ydim',xdim,ydim)
        
        # find centers
        ccx,ccy = (round(dx/2),round(dy/2))
        czx,czy = (round(xdim/2),round(ydim/2))
        print('ccx,ccy,czx,czy',ccx,ccy,czx,czy)
        
        # find indices
        sx = czx - ccx
        ex = dx + sx
        sy = czy - ccy
        ey = dy + sy

        print('sx,ex,sy,ey',sx,ex,sy,ey)
        dfile[:,sy:ey,sx:ex,:] = data[:,:,:,:]

        return filename, dfile



    def load_header(self):
        '''
        parses parameters from header file; checks line by line if line starts with keyword;
        uses first instance of keyword unless keyword in per_frame (in which case uses np.array)
        '''

        hdr_file = open(self.header_file, 'r')
        hdr_string = hdr_file.read()
        hdr_lines = hdr_string.split('\n')

        kwrds = self.keywords
        integers = self.integers
        strings = self.strings
        per_frame = self.per_frame
        params = {kw : None for kw in kwrds}

        for kw in kwrds:
            for line in hdr_lines:
                kv = params[kw]
                try:
                    if kw ==  line.strip().split(' ')[0]:
                        if kw in per_frame:
                            if kv is None:
                                params[kw] = np.array([])
                            params[kw] = np.append(params[kw], float(line.strip().split(' ')[1]))
                        elif kv is None:
                            ks = line.strip().split(' ')[1]
                            if kw in integers:
                                params[kw] = int(ks)
                            elif kw in strings:
                                params[kw] = ' '.join(line.strip().split(' ')[1:])
                            else:
                                params[kw] = float(ks)
                except IndexError:
                    pass

        ok_miss = ['animal_number','subject_weight','dose','injection_time']
        failed = [kw for kw in kwrds if params[kw] is None and kw not in ok_miss]
        if any(failed):
            raise ValueError('Failed to parse parameters: {}'.format(', '.join(failed)))
        hdr_file.close()

        for s in self.strings:
            params[s] = '' if params[s] is None else params[s]

        self.params = Params(**params)
        return


    def load_image(self,plane_range=None,frame_range=None,unscaled=False):
        '''
        - loads specified frames into np.ndarray
        - can do range of frames now; maybe implement list of frames
        - same for z-dimension
        - does not support selection over x,y dimensions
        - returns scaled image data; 
        - planes and frames should both be tuples corresponding to the range of planes and frames to be
        returned from the image data; 
        - defaults to all data; 
        - for single plane or single frame, just give n where n is the index
        of the plane or frame to include; 
        - index from 0, e.g. for the first 40 planes, use [0,39]
        '''
        def read_chunks(ifr):
            '''
            Trying to read data in chunks to handle HiResCt images
            '''
            to_read = bpp*matsize
            read_lim = self.data_lim
            # print('Will read {0} {1}MB chunks.'.format(to_read/read_lim,int(read_lim/10**6)))
            ix = 0
            while to_read > read_lim:
                # print('Reading new chunk; {}MB left'.format(int(to_read/10**6)))
                nbytes = read_lim
                npixels = int(nbytes/bpp)
                chunk = np.array(struct.unpack(sf*npixels,img_file.read(nbytes)))
                imgmat[ifr][ix:ix+npixels] = chunk
                to_read -= read_lim
                ix+=npixels

            # print('Reading new chunk; {}MB left'.format(int(to_read/10**6)))
            nbytes = to_read
            npixels = int(nbytes/bpp)
            chunk = np.array(struct.unpack(sf*npixels,img_file.read(nbytes)))
            imgmat[ifr][ix:ix+npixels] = chunk



        x,y,z,fs = self.params.x_dimension,self.params.y_dimension,self.params.z_dimension,self.params.total_frames
        print('File dimensions: ({},{},{},{})'.format(x,y,z,fs))
        ps = self.params

        if self.tempdir is None:
            self.tempdir = tempfile.mkdtemp()

        if plane_range is None:
            if ps.z_dimension > 1:
                plane_range = [0, ps.z_dimension-1]
            else:
                plane_range = [0,0]
        elif type(plane_range) is int:
            plane_range = [plane_range,plane_range]
        else:
            plane_range = list(plane_range)
            if plane_range[-1] >= self.params.z_dimension:
                plane_range[-1] = self.params.z_dimension-1
                warnings.warn('Input z-plane range exceeds number of z-planes in data file.  Usings z-planes {}.'.format(plane_range))


        if frame_range is None:
            if ps.total_frames > 1:
                frame_range = [0, ps.total_frames-1]
            else:
                frame_range = [0,0]
        elif type(frame_range) is int:
            frame_range = [frame_range,frame_range]
        else:
            frame_range = list(frame_range)
            if frame_range[-1] >= self.params.total_frames:
                frame_range[-1] = self.params.total_frames-1
                warnings.warn('Input frame range exceeds number of frames in data file.  Usings frames {}.'.format(frame_range))


        if plane_range[1]>plane_range[0]:
            multi_plane = True
        else:
            multi_plane = False
        if frame_range[1]>frame_range[0]:
            multi_frame = True
        else:
            multi_frame = False


        pl,fr = plane_range,frame_range
        self.plane_range,self.frame_range = pl,fr

        
        # some calcs with params
        if self.type == 'pet':
            axial_fov=ps.axial_blocks*ps.axial_crystals_per_block*ps.axial_crystal_pitch+ps.axial_crystal_pitch
            Iz_size=ps.z_dimension
            Iz_pixel=axial_fov/ps.z_dimension
            aspect=Iz_pixel/ps.pixel_size
            calib_scale_factor=ps.scale_factor*(ps.calibration_factor/ps.isotope_branching_fraction);
            
        
        # which planes/frames to use
        npl = len(pl)
        nfr = len(fr)

        if npl > 2:
            raise ValueError('Input plane range invalid format: {}'.format(pl))
        else:
            if not multi_plane:
                pl1 = pl[0]
                pl2 = pl[0]
                planes = [pl1,]
                nplanes = 1
            else:
                pl1 = pl[0]
                pl2 = pl[1]
                planes = range(pl1,pl2+1)
                nplanes = len(planes)

        if nfr > 2:
            raise ValueError('Input frame range invalid format: {}'.format(fr))
        else:
            if not multi_frame:
                fr1 = fr[0]
                fr2 = fr[0]
                frames = [fr1,]
                nframes = 1
            else:
                fr1 = fr[0]
                fr2 = fr[1]
                frames = range(fr1,fr2+1)
                nframes = len(frames)
        self.nframes = nframes
                
            
        # file data format parameters
        bytes_per_pixel = {
            1:1,
            2:2,
            3:4,
            4:4
        }

        bpp = bytes_per_pixel[ps.data_type]
        self.bpp = bpp
        sf = self.struct_flags[ps.data_type]

        # read data from file
        print('Reading microPET image data...')
        
        img_file = open(self.filepath,'rb')
        matsize = ps.x_dimension*ps.y_dimension*nplanes
        pl_offset = pl[0]*(ps.x_dimension*ps.y_dimension)

        # make tempfile for whole image
        img_temp_name = os.path.join(self.tempdir,'{}.dat'.format(self.filename.split('.')[0]))
        imgmat = np.memmap(img_temp_name,mode='w+',dtype='float32',shape=(nframes,matsize))
        
        for ifr in frames:  
            fr_offset = ifr*(ps.x_dimension*ps.y_dimension*ps.z_dimension)
            img_file.seek(bpp*(fr_offset+pl_offset))
            read_chunks(ifr)
        imgmat = imgmat.swapaxes(0,1)
        img_file.close()

        # scale data
        if unscaled:
            self.img_data = imgmat
            self.scaled = False
        else:
            imgmat = imgmat.reshape(nplanes,ps.x_dimension,ps.y_dimension,nframes)
            if multi_plane and (not multi_frame):
                imgmat = imgmat[0:nplanes,:,:,0]
                self.scale_factor = ps.scale_factor[fr1]
            elif (not multi_plane) and multi_frame:
                imgmat = imgmat[0,:,:,0:nframes]
                self.scale_factor = ps.scale_factor[fr1:fr2+1]
            elif (not multi_plane) and (not multi_frame):
                imgmat = imgmat[0,:,:,0]
                self.scale_factor = ps.scale_factor[fr1]
            else: 
                imgmat = imgmat[0:nplanes,:,:,0:nframes]      
                self.scale_factor = ps.scale_factor[fr1:fr2+1]
            imgmat = imgmat*self.scale_factor
            self.img_data = imgmat.reshape(nplanes,ps.y_dimension,ps.x_dimension,nframes)
            self.scaled = True

        self.rotate_on_axis('x')
        return
        
    def save_cut(self,index,path):

        def add_animal_number(hdr_lines,animal_number):
            for i,line in enumerate(hdr_lines):
                if line.strip().startswith('subject_identifier'):
                    return hdr_lines[:i+1] + [
                            '#','# animal_number (string)', '#',
                            'animal_number {}'.format(animal_number.strip())
                            ] + hdr_lines[i+1:]

        def change_line(hdr_lines,hdr_var,value):
            '''
            Update line to match value in parameters (user input)
            '''
            for j,line in enumerate(hdr_lines):
                if line.strip().startswith(hdr_var+' '):
                    hdr_lines[j] = ' '.join([hdr_var,value])
                    break
            return hdr_lines

        def write_chunks(data, dfile):
            '''
            Trying to read data in chunks to handle HiResCt images
            '''
            if self.bpp is None:
                raise ValueError('self.bpp not defined in self.save_cuts')
            bpp = self.bpp

            total_pixels = len(data)
            bytes_to_write = total_pixels*bpp
            write_lim = self.data_lim
            print('Will write {0} {1}MB chunks.'.format(bytes_to_write/write_lim,int(write_lim/10**6)))
            ix = 0
            while bytes_to_write > write_lim:
                print('Writing new chunk; {}MB left'.format(int(bytes_to_write/10**6)))
                nbytes = write_lim
                npixels = int(nbytes/bpp)
                chunk = data[ix:ix+npixels]
                dfile.write(struct.pack(npixels*sf, *chunk))
                bytes_to_write -= write_lim
                ix += npixels

            print('Writing new chunk; {}MB left'.format(int(bytes_to_write/10**6)))
            nbytes = bytes_to_write
            npixels = int(nbytes/bpp)
            chunk = data[ix:ix+npixels]
            dfile.write(struct.pack(npixels*sf, *chunk))
            return



        print('Saving files...')
        if not self.cuts:
            raise ValueError('Image has not been cut in BaseImage.save_cuts()')
        if path is None:
            raise ValueError('Path not specified')
        sf  = self.struct_flags[self.params.data_type]

        hdr_file = open(self.header_file, 'r')
        hdr_string = hdr_file.read()
        hdr_lines = hdr_string.split('\n')

        '''
        Might need to be careful of aliasing, memory, memmaps here.  will image be flipped if saving is interrupted
        by overwrite warning on a cut besides the first?
        '''

        cut_img = self.cuts[index]
            
        # did this when reading image data, flip it back now
        cut_img.rotate_on_axis('x')
        
        # update header variables
        cut_hdr_lines = hdr_lines
        vars_to_update = ['x_dimension','y_dimension','z_dimension','subject_weight']
        if self.type == 'pet':
            vars_to_update += ['dose', 'injection_time']

        for v in vars_to_update:
            cut_hdr_lines = change_line(cut_hdr_lines,v,str(getattr(cut_img.params,v)))
        
        # add animal_number to header information if it has been set
        animal_number = cut_img.params.animal_number
        if animal_number.strip():
            cut_hdr_lines = add_animal_number(cut_hdr_lines,animal_number)


        cut_filename = cut_img.out_filename
        #print('cut_filename ', cut_filename)
        cut_hdr_name = cut_filename+'.hdr'
        cut_hdr_str = '\n'.join(cut_hdr_lines)

        #print('writing header to ',os.path.join(path,cut_hdr_name))
        with open(os.path.join(path,cut_hdr_name),'w') as hf:
            hf.write(cut_hdr_str)

        out_data = cut_img.img_data
        #print('out_data.shape',out_data.shape)
        
        out_data = out_data.reshape(cut_img.xdim*cut_img.ydim*cut_img.zdim,cut_img.nframes)

        if self.scaled:
            inv = lambda x: 1/x
            v_inv = np.vectorize(inv)
            inv_scale_factor = v_inv(self.scale_factor)
            out_data = out_data*inv_scale_factor

        # prepare data to write out
        out_data = out_data.swapaxes(0,1).flatten()
        
        # make sure data is int if it is supposed to be
        if sf in ['i','B','h']:
            out_data = out_data.astype(int)
        print('writing microPET image to ',os.path.join(path,cut_filename))
        with open(os.path.join(path,cut_filename),'wb') as dfile:
            write_chunks(out_data,dfile)
        print('File saved.')

        # clean up after myself.
        cut_img.rotate_on_axis('x')
        out_data = None
        gc.collect()


    def clean_cuts(self):
        '''
        remove existing cuts
        '''
        self.colors = [x for x in self.all_colors]
        for cut in self.cuts:
            try:
                delattr(cut,'img_data')
            except AttributeError:
                pass
            fn = '{}.dat'.format(cut.filename.split('.')[0])
            
            del cut
             
            fp = os.path.join(self.tempdir,fn)
            if os.path.exists(fp):
                try_rmfile(fp)

        self.cuts = []
        gc.collect()


    def unload_image(self):
        self.clean_cuts()
        self.img_data = None
        gc.collect()
        if self.tempdir:
            shutil.rmtree(self.tempdir)
        self.tempdir = None


    def get_axis(self,axis):
        '''
        converts axis x,y,z to 2,1,0 for use with numpy
        '''
        if axis not in ['x', 'y', 'z'] + list(range(3)):
            raise ValueError('Invalid axis input: {}\nUse axis in ["x","y",z",1,2,3].'.format(axis))
        try:
            axis = self.ax_map[axis]
        except KeyError:
            pass
        return axis

    def check_data(self):
        if self.img_data is None:
            raise ValueError('self.img_data has not been intialized. Use image.load_image()')
   
    def check_collapse_method(self,method):
        if method not in ['sum','mean','max']:
            raise ValueError('Unrecognized input collapse method: {}'.format(method))


    def get_frame(self,n):
        
        self.check_data()
       
        if self.frame_range is None:
            raise ValueError('self.frame_range has not been declared in self.get_frame()')

        f1,f2 = tuple(self.frame_range)
        if n not in range(f1,f2+1):
            raise IndexError('Specified frame {0} is not in loaded range {1}'.format(n,self.frame_range))
        return self.img_data[:,:,:,f1-n]

    def collapse_frame(self,axis,frame=None,method='sum'):
        if frame is None:
            matrix = self.img_data
        else:
            matrix = self.get_frame(frame)
        ax = self.get_axis(axis)
        self.check_collapse_method(method)
        cmatrix = getattr(matrix,method)(axis=ax)
        return cmatrix

    def collapse_over_frames(self,method,matrix=None):
        if matrix is None:
            matrix = self.img_data
        self.check_collapse_method(method)
        return getattr(self.img_data,method)(axis=3)

    def rotate_on_axis(self, axis, log=False):
        self.check_data()
        axis = self.get_axis(axis)
        if log:
            self.rotation_history.append(axis)
        axes_to_flip = [0,1,2]
        axes_to_flip.remove(axis)
        self.img_data = np.flip(self.img_data,axes_to_flip[0])
        self.img_data = np.flip(self.img_data,axes_to_flip[1])

    def split_on_axis(self,matrix,axis):
        axis = self.get_axis(axis)
        mats = np.split(matrix, matrix.shape[axis], axis=axis)
        mats = [np.squeeze(m) for m in mats]
        return mats


class SubImage(BaseImage):

    def __init__(self, parent_image, img_data, filename, cut_coords, linecolor='red'):

        self.filename = filename

        self.out_filename = filename

        BaseImage.__init__(self, filepath='./{}'.format(self.filename), img_data=img_data)
        self.type = parent_image.type
        self.parent_image = parent_image
        self.frame_range = parent_image.frame_range
        self.plane_range = parent_image.plane_range
        self.scaled = parent_image.scaled
        self.cut_coords = cut_coords
        shape = self.img_data.shape
        self.zdim, self.ydim, self.xdim, self.nframes = shape
        self.x_dimension,self.y_dimension,self.z_dimension = self.xdim,self.ydim,self.zdim
        self.params = copy.copy(parent_image.params)
        reset_params = ['animal_number', 'subject_weight', 'dose', 'injection_time']
        for p in reset_params:
            setattr(self.params,p,'')
        self.params.x_dimension,self.params.y_dimension,self.params.z_dimension, self.params.total_frames = self.xdim,self.ydim,self.zdim, self.nframes
        self.bounds={0 : (self.ydim, self.xdim), 
                    1 : (self.xdim, self.zdim),
                    2 : (self.zdim, self.ydim)}

        self.linecolor = linecolor



# make so can initialize with np matrix
class PETImage(BaseImage):

    def __init__(self, filepath, img_data=None):
        '''
        Needs header file and data file in same directory
        '''
        BaseImage.__init__(self, filepath=filepath, img_data=img_data)
        self.type = 'pet'

        # for header file info
        self.params = None
        self.keywords = ['axial_blocks',
                'axial_crystals_per_block',
                'axial_crystal_pitch',
                'data_type',
                'z_dimension',
                'x_dimension',
                'y_dimension',
                'pixel_size',
                'total_frames',
                'calibration_factor',
                'scale_factor',
                'isotope_branching_fraction',
                'frame_duration',
                'animal_number',
                'subject_weight',
                'dose',
                'injection_time']
        self.integers = ['data_type','z_dimension','total_frames','x_dimension','y_dimension']
        self.per_frame = ['scale_factor','frame_duration'] 
        self.strings = ['injection_time','animal_number','subject_weight','dose']


        self.header_file = filepath+'.hdr'

        self.load_header()  # initialize params
        self.xdim = self.params.x_dimension
        self.ydim = self.params.y_dimension
        self.zdim = self.params.z_dimension
        self.x_dimension,self.y_dimension,self.z_dimension = self.xdim,self.ydim,self.zdim

        self.frame_range = None
        self.plane_range = None
        self.nframes = None

        self.bounds={0 : (self.ydim, self.xdim), 
                    1 : (self.xdim, self.zdim),
                    2 : (self.zdim, self.ydim)}
        self.scaled = None

class CTImage(BaseImage):

    def __init__(self, filepath, img_data=None):
        BaseImage.__init__(self, filepath=filepath, img_data=img_data)
        self.type = 'ct'
        self.params = None
        self.header_file = filepath+'.hdr'

        self.keywords = [
                'data_type',
                'z_dimension',
                'x_dimension',
                'y_dimension',
                'pixel_size',
                'total_frames',
                'calibration_factor',
                'scale_factor',
                'animal_number',
                'frame_duration',
                'subject_weight']

        self.integers = ['data_type','z_dimension','total_frames','x_dimension','y_dimension']
        self.per_frame = ['scale_factor','frame_duration'] 
        self.strings = ['animal_number','subject_weight']
        self.load_header()
        self.xdim = self.params.x_dimension
        self.ydim = self.params.y_dimension
        self.zdim = self.params.z_dimension
        self.x_dimension,self.y_dimension,self.z_dimension = self.xdim,self.ydim,self.zdim

        self.frame_range = None
        self.plane_range = None
        self.nframes = None

        self.bounds={0 : (self.ydim, self.xdim), 
                    1 : (self.xdim, self.zdim),
                    2 : (self.zdim, self.ydim)}
        self.scaled = None


# functions
def try_rmfile(path):
    try:
        os.remove(path)
    except Exception as e:
        print(e)
        print('Failed to remove file: {}'.format(os.path.split(path)[1]))
        
"""
Rectangle manipulation
"""        
class Rect:
    def overlaps(self,other):
        a, b = self, other
        xlt = max(min(a.xlt, a.xrb), min(b.xlt, b.xrb))
        ylt = max(min(a.ylt, a.yrb), min(b.ylt, b.yrb))
        xrb = min(max(a.xlt, a.xrb), max(b.xlt, b.xrb))
        yrb = min(max(a.ylt, a.yrb), max(b.ylt, b.yrb))
        return xlt<xrb and ylt<yrb
    
    def intersection(self, other):
        a, b = self, other
        xlt = max(min(a.xlt, a.xrb), min(b.xlt, b.xrb))
        ylt = max(min(a.ylt, a.yrb), min(b.ylt, b.yrb))
        xrb = min(max(a.xlt, a.xrb), max(b.xlt, b.xrb))
        yrb = min(max(a.ylt, a.yrb), max(b.ylt, b.yrb))
        if xlt<=xrb and ylt<=yrb:
            return type(self)(xlt, ylt, xrb, yrb)   
    
    def wid(self):
        return self.xrb-self.xlt
    def ht(self):
        return self.yrb-self.ylt
    def ctr(self):
        return self.xlt+self.wid()*.5,self.ylt+self.ht()*.5
    
    def expand(self, m):
        self.xlt-=m[0]; self.xrb+=m[0];
        self.ylt-=m[1]; self.yrb+=m[1];
        
    def adjust_to_size(self,sz):
        #print ('adjust_to_size: {}'.format(sz))
        #print(self)
        sz0,x0,x1=np.array(sz),np.array([self.xlt,self.ylt]),np.array([self.xrb,self.yrb])        
        d=(sz0-(x1-x0))*.5;x0n=(x0-d).astype(int); x1n=x0n+sz0
        self.xlt,self.ylt,self.xrb,self.yrb=x0n[0],x0n[1],x1n[0],x1n[1]
        #print ('adjusted:')
        #print(self)
        
    def adjust_to_center(self,cx,cy):
        print ('adjust to center: ',str(cx),str(cy))
        print(str(self))
        c,x0,x1=np.array([cx,cy]),np.array([self.xlt,self.ylt]),np.array([self.xrb,self.yrb])
        c0=np.array(self.ctr())
        d=(c-c0).astype(int)
        x0+=d; x1+=d;
        self.xlt,self.ylt,self.xrb,self.yrb=x0[0],x0[1],x1[0],x1[1]
        print('adusted,',str(self))
        
    def __str__(self):
        return "Rectangle, wid={}, ht={}, ctr=({},{}), l,t,r,b=({},{},{},{})".format(
            self.wid(),self.ht(),self.ctr()[0],self.ctr()[1],self.xlt,self.ylt,self.xrb,self.yrb)
    
    @staticmethod
    def union_list(rects):
        if len(rects)<1: return None
        out=rects[0]
        for i in range(len(rects)):
            out=out.union(rects[i])
        return out
            
    def union(self, other):
        a,b=self,other
        return type(self) (verts=[min(a.xlt,b.xlt),min(a.ylt,b.ylt),max(a.xrb,b.xrb),max(a.yrb,b.yrb)])
        
    def __init__(self, bb=None, verts=None):
        if bb is not None:
            self.xlt, self.ylt, self.xrb, self.yrb = bb[1],bb[0],bb[3],bb[2]
        if verts is not None:
            self.xlt, self.ylt, self.xrb, self.yrb = verts[0],verts[1],verts[2],verts[3]        
            
    def area(self):
        return float(self.xrb-self.xlt)*(self.yrb-self.ylt)
    
    def pt_inside(self, pt):
        return pt[0]>self.xlt and pt[0]<self.xrb and pt[1]>self.ylt and pt[1]<self.yrb
    
    #for a pt inside, return its quadrant.
    def quadrant(self,pt):
        c=self.ctr()
        tl,tr=Rect(verts=[self.xlt,self.ylt,c[0],c[1]]),Rect(verts=[c[0],self.ylt,self.xrb,c[1]])
        bl,br=Rect(verts=[self.xlt,c[1],c[0],self.yrb]),Rect(verts=[c[0],c[1],self.xrb,self.yrb])
        if tl.pt_inside(pt): return 'lt'
        elif tr.pt_inside(pt): return 'rt'
        elif bl.pt_inside(pt): return 'lb'
        elif br.pt_inside(pt): return 'rb'
        else: return 'ot'    
    
    def subimage(self,img):
        xl,xr,yt,yb = int(round(max(self.xlt,0))), int(round(min(self.xrb,img.shape[0]-1))), \
            int(round(max(self.ylt,0))), int(round(min(self.yrb,img.shape[1]-1)))
        return img[yt:yb,xl:xr]
    
    def significant_intersection(self,other,ratio=0.5):
        a,b=self,other
        c=a.intersection(b)
        if c is None: 
            return False
        s1,s2,s3=a.area(),b.area(),c.area()
        if s3!=0: 
            return (min(s1,s2)/s3 >= ratio)
        else:
            return False
#end class Rect

# %%
dir1='/home/wustl/mmilchenko/src/ccdb/Pre-Clinical_Data_Samples/Concorde_Microsystems_F220_Scanner/'
dir2='/home/wustl/mmilchenko/src/ccdb/Pre-Clinical_Data_Samples/Siemens_Inveon_Scanner/'

imagesStatic=[ dir1+ '1_Bed/Static/mpet3681a_em1_v1.img', 
        dir1+'4_Bed/Static/mpet3719b_em1_v1.img',
        dir1+'2_Bed/Static/mpet3723b_em1_v1.img',
        dir2+'1_Bed/Static/PET/mpet3631a_em1_v1.pet.img',
        dir2+'1_Rat/Static/PET/mpet3617a_em1_v1.pet.img',
        dir2+'2_Bed/Static/PET/mpet3742a_em1_v1.pet.img',
        dir2+'4_Bed/Static/PET/mpet3745a_em1_v1.pet.img'
       ]
imagesDynamic=[ dir1+'1_Rat/Dynamic/mpet3659b_em1_v1.img',
               dir1+'2_Bed/Dynamic/mpet3688a_em1_v1.img',
               dir1+'4_Bed/Dynamic/mpet3691b_em1_v1.img',
               dir2+'1_Bed/Dynamic/PET/mpet3715b_em1_v1.pet.img',
               dir2+'1_Rat/Dynamic/PET/mpet3739a_em1_v1.pet.img',
               dir2+'2_Bed/Dynamic/PET/mpet3741a_em1_v1.pet.img',
               dir2+'4_Bed/Dynamic/PET/mpet3721a_em1_v1.pet.img'
]

imagesCT=[ dir2+'1_Bed/Static/CT/mpet3631a_ct1_v1.ct.img',
          dir2+'1_Rat/Static/CT/mpet3617a_ct1_v1.ct.img',
          dir2+'2_Bed/Static/CT/mpet3742a_ct1_v1.ct.img',
          dir2+'4_Bed/Static/CT/mpet3745a_ct1_v1.ct.img',
          dir2+'1_Bed/Dynamic/CT/mpet3715b_ct1_v1.ct.img',
          dir2+'1_Rat/Dynamic/CT/mpet3739a_ct1_v1.ct.img',
          dir2+'2_Bed/Dynamic/CT/mpet3741a_ct1_v1.ct.img',
          dir2+'4_Bed/Dynamic/CT/mpet3721a_ct1_v1.ct.img'
]
s="1"
with open('/home/shared/NRG/mmilchenko/temp/microPET/PET/test_files.lst','r') as f:
    images_test=f.read().splitlines()

with open('/home/shared/NRG/mmilchenko/temp/microPET/CT/test_files_ct.lst','r') as f:
    images_test_ct=f.read().splitlines()

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
#splitter of mice.
class SoM:
    ipw_on=False
    
    def __init__(self,file,modality=None):
        self.filename=file
        self.pi,self.modality=SoM.load_image(file,modality)
    
    @staticmethod
    def add_cuts_to_image(im,boxes,desc_map,save_analyze_dir=None):
        
        ims=[]
        
        mag=2 if isinstance(im,PETImage) else 0.5        
        for b in boxes:
            r,desc=b['rect'],desc_map[b['desc']]
            ix=len(im.cuts)+1
            xmax,xmin=int(round(r.xrb)),int(round(r.xlt))
            ymax,ymin=int(round(r.yrb)),int(round(r.ylt))
            #print('xmax={},xmin={},ymax={},ymin={}'.format(xmax,xmin,ymax,ymin))
            fname=im.filename[:-4]+'_'+desc
            data=im.img_data[:,ymin:ymax,xmin:xmax,:]
            d,h,w=data.shape[0],data.shape[1],data.shape[2]
            
            
            if data.shape[3]==1:
                ims+=[SoM.a2im(im,np.squeeze(data[:,:,int(round(w*.5)),0]),mag,False)]
            else:
                t2=int(data.shape[3]/2)
                ims+=[SoM.a2im(im,np.squeeze(data[:,:,int(round(w*.5)),t2]),mag,False)]

            #_,data=im.submemmap(ix=ix,data=im.img_data[:,ymin:ymax,xmin:xmax,:])
            #print(data.shape)

            new_img=SubImage(parent_image=im,img_data=data,filename=fname+'.img', 
                             cut_coords=[(xmin,xmax),(ymin,ymax)])
            #print('adding '+fname+'.img')
            #print('saving '+fname)
            if save_analyze_dir is not None:
                SoM.write_analyze(new_img,save_analyze_dir+'/'+fname+'_analyze.img')
            im.cuts.append(new_img)
        if SoM.ipw_on:
            print('split images(midsagittal slice)')
            box=ipw.HBox(ims)
            display(box)
        return ims
    
    @staticmethod
    def write_analyze(im,filepath):
        id1=np.swapaxes(im.img_data,0,2)
        ps=im.params.pixel_size
        hdr=nibabel.AnalyzeHeader()
        hdr.set_data_shape(id1.shape)
        hdr.set_data_dtype(id1.dtype)
        hdr.set_zooms([ps,ps,ps,im.params.frame_duration[0]])
        analyze_img=nibabel.AnalyzeImage(id1,None,hdr)
        print('writing Analyze 7.5 image: '+filepath)
        analyze_img.to_filename(filepath)
     
    @staticmethod
    def a2im(pi,a,r,return_array=False):
        if isinstance(pi,PETImage): return SoM.a2im_pet(a,r,return_array)
        elif isinstance(pi,CTImage): return SoM.a2im_ct(a,r,return_array)
        else: return None
        
    
    @staticmethod
    def z_compress_pet(pi):
        n=12
        img=pi.img_data
        if len(img.shape)==3:
            imgz=np.squeeze(np.sum(img,axis=0))
        elif len(img.shape)==4:
            imgz=np.squeeze(np.sum(img,axis=(0,3)))
        im=filters.gaussian(imgz, sigma=1/(4.*n))
        return im
    
    @staticmethod
    def merge_im_arrays(im0,im1,orientation='horizontal',bg=0):
        a=im0; ash=np.array(a.shape)
        b=im1; bsh=np.array(b.shape)
        msh=np.maximum(np.array(a.shape),np.array(b.shape))
        da=msh-a.shape; db=msh-b.shape
        if orientation=='horizontal':
            ap=np.pad(a,[(0,da[0]),(0,0)],constant_values=bg)
            bp=np.pad(b,[(0,db[0]),(0,0)],constant_values=bg)
            #print(ap.shape,bp.shape)
            #print(a.dtype,b.dtype)
            im=np.concatenate((ap,bp),1)
        else:
            ap=np.pad(a,[(0,da[1]),(0,0)],constant_values=bg)
            bp=np.pad(b,[(0,db[1]),(0,0)],constant_values=bg)
            #print(ap.shape,bp.shape)
            im=np.concatenate((ap,bp),0)
        return im

    def split_mice(self,outdir,save_analyze=False,num_anim=None,
                   sep_thresh=None,margin=None,minpix=None,output_qc=False,suffix_map=None):
        
        d={'l':'l','r':'r','ctr':'ctr','lb':'lb','rb':'rb','lt':'lt','rt':'rt'}
        if suffix_map is not None: 
            for s in suffix_map.split(','): 
                mp=s.split(':')
                if len(mp)<2: continue
                if mp[0] in d.keys(): d[mp[0]]=mp[1]
                
        if self.modality=='PET': return self.split_mice_pet(outdir,d,save_analyze,num_anim,
                sep_thresh,margin,minpix,output_qc,d)
        if self.modality=='CT': return self.split_mice_ct(outdir,d,save_analyze,num_anim,
                sep_thresh,margin,minpix,output_qc,d)
        else: return -1
             
    @staticmethod
    def detect_animals(im):
        blobs= im > SoM.sep_thresh * np.mean(im)
        #all_labels = measure.label(blobs)
        (blobs_labels,num) = measure.label(blobs, return_num=True,background=0)
        return blobs_labels,num            
        
    @staticmethod    
    def get_valid_regs(label):
        min_pts=SoM.minpix
        m=[SoM.margin,SoM.margin]
        props=measure.regionprops(label)
        areas=[p.area for p in props]
        print('areas'+str(areas))
        valid_reg=[ p for p in props if p.area >= min_pts  ]        
        print('valid regions detected: '+str(len(valid_reg)))
        return valid_reg
    
    
    @staticmethod
    def harmonize_rects(rects):
        nrect=len(rects)
        if nrect==1:
            r=rects['ctr']; sz=int(round(max(r.wid(),r.ht())))
            r.adjust_to_size([sz,sz])
        elif nrect==2:
            rl,rr=rects['l'],rects['r']
            w=int(round(rr.ctr()[0]-rl.ctr()[0]))
            rl.adjust_to_size([w,w]); rr.adjust_to_size([w,w])
        elif nrect==3 or nrect==4:
            rs=[ l['rect'] for l in rects ]
            rs.sort(key=lambda r:r.xlt)
            w=rs[-1].ctr()[0]-rs[0].ctr()[0]
            rs.sort(key=lambda r:r.ylt)
            h=rs[-1].ctr()[1]-rs[0].ctr()[1]
            print('harmonize_rects, nrect={}, w: {}, h: {}'.format(nrect,w,h))
            sz=int(round(max(w,h))); s=[sz,sz]
            for r in rs: r.adjust_to_size(s)

    @staticmethod
    def split_coords(img,valid_reg,mag=4):
        ims=[]
        out_boxes=[]
        m=[SoM.margin,SoM.margin]
        print('split images (axial projection):')
        if len(valid_reg)==1:
            bb=valid_reg[0].bbox
            r=Rect(bb=bb); r.expand(m); SoM.harmonize_rects({'ctr':r})
            out_boxes+=[{'desc':'ctr','rect':r}]

        elif len(valid_reg)==2:        
            bb1,bb2=valid_reg[0].bbox,valid_reg[1].bbox
            
            if bb1[1]<bb2[1]: rl=Rect(bb=bb1); rr=Rect(bb=bb2)
            else: rl=Rect(bb=bb2); rr=Rect(bb=bb1)
            rl.expand(m); rr.expand(m); 
            SoM.harmonize_rects({'l':rl,'r':rr})
            out_boxes+=[{'desc':'l','rect':rl},{'desc':'r','rect':rr}]
        
        elif len(valid_reg)==3 or len(valid_reg)==4:
            rs=[Rect(bb=valid_reg[i].bbox) for i in range(len(valid_reg))]
            big_box=Rect.union_list(rs)
            lr=[ {'desc':big_box.quadrant(r.ctr()),'rect':r} for r in rs ]
            SoM.harmonize_rects(lr)
            out_boxes=lr
        return out_boxes
    
    @staticmethod
    def refine_cuts_ct(cuts,imz):
        sz=imz.shape
        for box in cuts:
            r=box['rect']
            cx,cy,n=0.,0.,0.            
            for y in range(max(0,r.ylt),min(r.yrb,sz[0])):
                for x in range(max(0,r.xlt),min(r.xrb,sz[1])):
                    if imz[y,x]==0: continue
                    cx+=x; cy+=y; n+=1
            r.adjust_to_center(cx/n, cy/n)
        return cuts
            
    
    @staticmethod
    #статическій мѣтодъ
    def z_compress_ct(pi,thresh,binary=True):
        n=12;  img=pi.img_data; sh=img.shape; nsl=sh[0]
        sl=np.zeros((sh[1],sh[2])).astype('float32')
        for z in range(nsl):
            slm=np.squeeze(img[z,:,:])
            if binary: slm=np.where(slm>thresh,1,0)
            sl+=slm
        
        sl/=float(nsl)
        if binary:            
            return sl/float(nsl),skimage.morphology.binary_opening(sl,skimage.morphology.disk(10))
        else:
            return np.squeeze(img[int(nsl/2),:,:]),None
    
    def detect_animals_ct(im,thresh):
        print('mean: ',np.mean(im))
        blobs= im > thresh
        (blobs_labels,num) = measure.label(blobs, return_num=True,background=0)
        return blobs_labels,num
    
    @staticmethod
    def a2im_pet(a,r,return_array=False):
        if not SoM.ipw_on and not return_array: return None
        f=BytesIO()
        b=0.3
        im0=(a/(np.max(a)*b))
        im0[im0>1]=1
        arr=np.uint8(im0*255)
        if return_array: return arr
        if not SoM.ipw_on: return None
        img=Image.fromarray(arr)
        img.save(f,'png')
        layout={'width':str(r*a.shape[1])+'px','height':str(r*a.shape[0])+'px'}
        #print(layout)
        return ipw.Image(value=f.getvalue(),layout=layout)
    
    @staticmethod
    def a2im_ct(a,r,return_array=False):
        im0=np.float64(a); im0[im0<0]=0; im0[im0>200.]=200.
        arr=np.uint8((im0/np.max(im0))*255.)
        
        if return_array: return arr
        if not SoM.ipw_on: return None
        
        f=BytesIO();  img=Image.fromarray(arr); img.save(f,'png')
        layout={'width':str(r*a.shape[1])+'px','height':str(r*a.shape[0])+'px'}
        return ipw.Image(value=f.getvalue(),layout=layout)
    
    @staticmethod
    def get_sag_image(img_data):
        #print('get_sag_image shape:',img_data.shape)
        sh=img_data.shape
        if len(sh)<4:
            return np.squeeze(img_data[:,np.int(sh[1]/2),:])        
        else:
            return np.squeeze(img_data[:,np.int(sh[1]/2),:,np.int(sh[3]/2)])
                
    @staticmethod
    def combine_images(images,mode='horizontal'):
        widths, heights = zip(*(i.size for i in images))
        if mode=='horizontal':
            total_width,max_height = sum(widths),max(heights)
            new_im = Image.new('RGB', (total_width, max_height))
            x_offset = 0
            for im in images: 
                new_im.paste(im, (x_offset,0));  x_offset += im.size[0]
            return new_im
        else:
            total_height=sum(heights)
            max_width=max(widths)
            new_im=Image.new('RGB', (max_width,total_height))
            y_offset=0
            for im in images:
                new_im.paste(im,(0,y_offset)); y_offset += im.size[1]
            return new_im
        
    @staticmethod
    def display_pil_image(im):
        if SoM.ipw_on:
            f=BytesIO()
            im.save(f,'png')
            display(ipw.HBox([ipw.Image(value=f.getvalue())]))
        
    @staticmethod
    def load_image(file,modality=None):                
        detect_mod=None
        try:
            print ('checking if PET modality')
            pi=PETImage(file); pi.load_header()
            detect_mod='PET'
        except Exception as e:
            print(str(e))
            pi=None            
                        
        if pi==None:
            try:
                print ('checking if CT modality')
                pi=CTImage(file);pi.load_header()
                detect_mod='CT'
            except Exception as e:
                print(str(e))
                pi=None
        
        if pi is None:
            print('Could not load image as PET or CT modality')
            return None,None
        
        if modality is not None and detect_mod!=modality:
            print(modality,' modality expected, but ',detect_mod,'detected, exiting')            
            return None,None
        print (detect_mod,' modality detected')
        pi.load_image()
        return pi,detect_mod        

    def split_mice_ct(self,outdir,desc_map,save_analyze=False,num_anim=None,
                   sep_thresh=None,margin=None,minpix=None,output_qc=False):
        print ('Splitting '+self.pi.filename)      
        SoM.num_anim=num_anim
        SoM.sep_thresh=0.99 if sep_thresh is None else sep_thresh
        SoM.margin=20 if margin is None else margin
        SoM.minpix=4000 if minpix is None else minpix
        pi=self.pi        
        rt=outdir+'/'+pi.filename[:-4]        
        
        #imz0: нормальная cумма всѣхъ бинарныхъ сѣченій. imz: открытая область (бинарная)
        imz0,imz=SoM.z_compress_ct(pi,50)
        blobs_labels,num=SoM.detect_animals_ct(imz,0.1)
        rects=SoM.get_valid_regs(blobs_labels)
        cuts=SoM.split_coords(imz,rects,1)
        save_analyze_dir=outdir if save_analyze else None
        #save_analyze_dir=None #debug
        ims=SoM.add_cuts_to_image(pi,cuts,desc_map,save_analyze_dir)
        #write the images.
        for ind in range(len(pi.cuts)):
            #pass #debug
            pi.save_cut(ind,outdir+'/')
        
        if output_qc:
            im=SoM.qc_image(pi,blobs_labels,cuts,outdir)
            SoM.display_pil_image(im)
        pi.clean_cuts(); pi.unload_image()
        return 0
    
    def split_mice_pet(self,outdir,desc_map,save_analyze=False,num_anim=None,
                   sep_thresh=None,margin=None,minpix=None,output_qc=False):
        print ('Splitting '+self.pi.filename)
        SoM.num_anim=num_anim
        SoM.sep_thresh=0.9 if sep_thresh is None else sep_thresh
        SoM.margin=20 if margin is None else margin
        SoM.minpix=200 if minpix is None else minpix
        pi=self.pi        
        imz=SoM.z_compress_pet(pi)        
        blobs_labels,num=SoM.detect_animals(imz)
                
        if num_anim is not None:
            if num<num_anim:
                print('split_mice detected less regions ({}) than indicated animals({}), attempting to compensate'.
                     format(num,num_anim))
                while num < num_anim and self.sep_thresh<1:
                    self.sep_thresh += 0.01
                    blobs_labels,num=SoM.detect_animals(imz)
                if num<num_anim:
                    print('compensation failed')
                    pi.clean_cuts(); pi.unload_image(); return 1
            rects=measure.regionprops(blobs_labels)
            if num>num_anim:
                rects.sort(key=lambda p: p.area, reverse=True)
                rects=rects[:num_anim]
        else:
            rects=SoM.get_valid_regs(blobs_labels)
            if len(rects)>4:
                print('detected {}>4 regions, attempting to compensate'.format(len(rects)))
                inc=self.minpix*0.1
                while len(rects)>4:
                    self.minpix+=inc
                    rects=SoM.get_valid_regs(blobs_labels)
        cuts=SoM.split_coords(imz,rects)
        save_analyze_dir=outdir if save_analyze else None
        SoM.add_cuts_to_image(pi,cuts,desc_map,save_analyze_dir)
        
        if output_qc:
            im=SoM.qc_image(pi,blobs_labels,cuts,outdir)
            #debug
            #SoM.display_pil_image(im) 
        
        #write the images.        
        for ind in range(len(pi.cuts)):
            pi.save_cut(ind,outdir+'/')
        pi.clean_cuts(); pi.unload_image()
        return 0
    
    @staticmethod
    def standardize_range(im, ignore_min=False, pct=5):
        mx=np.percentile(im,100-pct)
        mn=0 if ignore_min else np.percentile(im,pct)
        im1=im; im1[im>mx]=mx; im1[im<mn]=mn; rng=mx-mn
        print('min,max,rng',mn,mx,rng)
        im1=((im1-mn)/rng)*255
        print('min_new,max_new',np.min(im1),np.max(im1))
        return im1
    
    @staticmethod
    def qc_image(pi,labels,rects_dict,outdir):    
        imz,itype=None,None
        
        if isinstance(pi,PETImage):
            imz=SoM.z_compress_pet(pi); itype='PET'            
            imz/=np.max(imz); linwid=1; alpha=0.1; pct=5
            
        elif isinstance(pi,CTImage):            
            imz,_=SoM.z_compress_ct(pi,SoM.sep_thresh,binary=False);itype='CT'
            pct=2
            imz=SoM.standardize_range(imz,pct=pct)
            imz/=np.max(imz); linwid=3; alpha=0.3; 
            #SoM.display_pil_image(Image.fromarray(imz).convert('RGB'))
            
        if imz is None: 
            print('qc_image: unknown image type'); return
        
        imz_qc=np.uint8(255*skimage.color.label2rgb(labels,image=imz,bg_label=0,alpha=alpha))
        #наложить области на изображеніе.                     
        imz_qc=Image.fromarray(imz_qc).convert('RGB')
        d=ImageDraw.Draw(imz_qc)
        colors=['lightblue','red','violet','lightgreen']
        for i in range(0,len(rects_dict)):
            rd=rects_dict[i]
            r=rd['rect']
            d.rectangle([r.xlt,r.ylt,r.xrb,r.yrb],outline=colors[i],width=linwid)
                   
        sag_ims=[ SoM.get_sag_image(pi.cuts[i].img_data) for i in range(len(pi.cuts)) ]        
        sag_ims_pil=[]
        for im in sag_ims:                
            im1=SoM.standardize_range(im,pct=pct); imp=Image.fromarray(im1).convert('RGB')
            sag_ims_pil+=[imp]
            #SoM.display_pil_image(imp)
        
        #sag_ims_pil= [ Image.fromarray(im).convert('RGB') for im in sag_ims ]  
        #SoM.display_pil_image(sag_ims_pil[0])
        
        si_dims=[sag_ims[0].shape]
        sag_im=SoM.combine_images(sag_ims_pil)
        d1=ImageDraw.Draw(sag_im)
        off=0
        for i in range (len(sag_ims)):
            sh=sag_ims[i].shape            
            d1.rectangle([off,0,off+sh[1]-1,sh[0]-1],outline=colors[i],width=linwid)
            off+=sh[1] 
        
        fname=outdir+'/'+pi.filename[:-4]+'_split_qc.png'
        qc_im=SoM.combine_images([imz_qc,sag_im])
        if itype=='PET': 
            w,h=qc_im.size; qc_im=qc_im.resize((w*3,h*3),resample=Image.BILINEAR)
        print('writing',fname)
        qc_im.save(fname,'png')
        return qc_im

# %%
d={'l':'lM','r':'rM','ctr':'ctrM','lb':'lbM','rb':'rbM','lt':'ltM','rt':'rtM'}
for i in range(0,len(images_test_ct)):
    print("test CT image ",str(i))
    s=SoM(images_test_ct[i])
    if s.pi is None: 
        print (images_test_ct[i], ': unknown image modality' )
        continue
    s.split_mice_ct('/home/wustl/mmilchenko/temp',d,save_analyze=False,output_qc=True)
# Out:
# test CT image  0
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3413a_ct1_v1.ct.img
# mean:  0.056919097900390625
# areas[14921]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3413a_ct1_v1.ct_ctrM.img
# Will write 5.7628088 10MB chunks.
# Writing new chunk; 57MB left
# Writing new chunk; 47MB left
# Writing new chunk; 37MB left
# Writing new chunk; 27MB left
# Writing new chunk; 17MB left
# Writing new chunk; 7MB left
# File saved.
# min,max,rng -1000.0 73.0 1073.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 576.0 1576.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3413a_ct1_v1.ct_split_qc.png
# test CT image  1
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3413b_ct1_v1.ct.img
# mean:  0.04857635498046875
# areas[12734]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3413b_ct1_v1.ct_ctrM.img
# Will write 3.7334912 10MB chunks.
# Writing new chunk; 37MB left
# Writing new chunk; 27MB left
# Writing new chunk; 17MB left
# Writing new chunk; 7MB left
# File saved.
# min,max,rng -1000.0 93.0 1093.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 503.5399999999936 1503.5399999999936
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3413b_ct1_v1.ct_split_qc.png
# test CT image  2
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3418a_ct1_v1.ct.img
# mean:  0.04798126220703125
# areas[12578]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3418a_ct1_v1.ct_ctrM.img
# Will write 5.0061312 10MB chunks.
# Writing new chunk; 50MB left
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# min,max,rng -1000.0 63.0 1063.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 525.0 1525.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3418a_ct1_v1.ct_split_qc.png
# test CT image  3
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3418b_ct1_v1.ct.img
# mean:  0.04749298095703125
# areas[11156, 1294]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3418b_ct1_v1.ct_ctrM.img
# Will write 3.038 10MB chunks.
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# min,max,rng -1000.0 53.0 1053.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 377.0200000000041 1377.020000000004
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3418b_ct1_v1.ct_split_qc.png
# test CT image  4
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3450a_ct1_v1.ct.img
# mean:  0.1222381591796875
# areas[7570, 6473, 535, 8805, 8661]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 207.5, h: 208.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct1_v1.ct_ltM.img
# Will write 5.8752512 10MB chunks.
# Writing new chunk; 58MB left
# Writing new chunk; 48MB left
# Writing new chunk; 38MB left
# Writing new chunk; 28MB left
# Writing new chunk; 18MB left
# Writing new chunk; 8MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct1_v1.ct_rtM.img
# Will write 5.8752512 10MB chunks.
# Writing new chunk; 58MB left
# Writing new chunk; 48MB left
# Writing new chunk; 38MB left
# Writing new chunk; 28MB left
# Writing new chunk; 18MB left
# Writing new chunk; 8MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct1_v1.ct_lbM.img
# Will write 5.8752512 10MB chunks.
# Writing new chunk; 58MB left
# Writing new chunk; 48MB left
# Writing new chunk; 38MB left
# Writing new chunk; 28MB left
# Writing new chunk; 18MB left
# Writing new chunk; 8MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct1_v1.ct_rbM.img
# Will write 5.8752512 10MB chunks.
# Writing new chunk; 58MB left
# Writing new chunk; 48MB left
# Writing new chunk; 38MB left
# Writing new chunk; 28MB left
# Writing new chunk; 18MB left
# Writing new chunk; 8MB left
# File saved.
# min,max,rng -1000.0 38.0 1038.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 144.0 1144.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 113.0 1113.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 166.0 1166.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 165.0 1165.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3450a_ct1_v1.ct_split_qc.png
# test CT image  5
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3450a_ct2_v1.ct.img
# mean:  0.1246490478515625
# areas[7944, 6600, 8819, 9313]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 202.5, h: 199.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct2_v1.ct_ltM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct2_v1.ct_rtM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct2_v1.ct_lbM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3450a_ct2_v1.ct_rbM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# min,max,rng -1000.0 56.0 1056.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 172.0 1172.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 147.0 1147.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 186.0 1186.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 173.0 1173.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3450a_ct2_v1.ct_split_qc.png
# test CT image  6
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3455a_ct1_v1.ct.img
# mean:  0.12173843383789062
# areas[7748, 6757, 8475, 8933]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 196.0, h: 200.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct1_v1.ct_ltM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct1_v1.ct_rtM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct1_v1.ct_lbM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct1_v1.ct_rbM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# min,max,rng -1000.0 28.0 1028.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 169.0 1169.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 173.0 1173.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 182.0 1182.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 169.0 1169.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3455a_ct1_v1.ct_split_qc.png
# test CT image  7
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3455a_ct2_v1.ct.img
# mean:  0.12108993530273438
# areas[7753, 7370, 7937, 8683]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 186.0, h: 201.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct2_v1.ct_ltM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct2_v1.ct_rtM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct2_v1.ct_lbM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3455a_ct2_v1.ct_rbM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# min,max,rng -1000.0 57.0 1057.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 505.0 1505.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 399.0 1399.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 607.0 1607.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 743.0 1743.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3455a_ct2_v1.ct_split_qc.png
# test CT image  8
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3459a_ct1_v1.ct.img
# mean:  0.052463531494140625
# areas[13753]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3459a_ct1_v1.ct_ctrM.img
# Will write 5.163795 10MB chunks.
# Writing new chunk; 51MB left
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# min,max,rng -1000.0 98.0 1098.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 975.0 1975.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3459a_ct1_v1.ct_split_qc.png
# test CT image  9
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3459b_ct1_v1.ct.img
# mean:  0.04543304443359375
# areas[11910]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3459b_ct1_v1.ct_ctrM.img
# Will write 3.4689248 10MB chunks.
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# min,max,rng -1000.0 38.0 1038.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 1040.0 2040.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3459b_ct1_v1.ct_split_qc.png
# test CT image  10
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3464a_ct1_v1.ct.img
# mean:  0.11402511596679688
# areas[5876, 6231, 837, 8060, 8887]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 191.5, h: 209.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct1_v1.ct_ltM.img
# Will write 5.9318798 10MB chunks.
# Writing new chunk; 59MB left
# Writing new chunk; 49MB left
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct1_v1.ct_rtM.img
# Will write 5.9318798 10MB chunks.
# Writing new chunk; 59MB left
# Writing new chunk; 49MB left
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct1_v1.ct_lbM.img
# Will write 5.9318798 10MB chunks.
# Writing new chunk; 59MB left
# Writing new chunk; 49MB left
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct1_v1.ct_rbM.img
# Will write 5.9318798 10MB chunks.
# Writing new chunk; 59MB left
# Writing new chunk; 49MB left
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# min,max,rng -1000.0 -11.0 989.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 379.0 1379.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 450.0 1450.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 659.0 1659.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 791.0 1791.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3464a_ct1_v1.ct_split_qc.png
# test CT image  11
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3464a_ct2_v1.ct.img
# mean:  0.11446762084960938
# areas[7127, 6529, 7825, 8526]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 191.5, h: 204.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct2_v1.ct_ltM.img
# Will write 5.6514528 10MB chunks.
# Writing new chunk; 56MB left
# Writing new chunk; 46MB left
# Writing new chunk; 36MB left
# Writing new chunk; 26MB left
# Writing new chunk; 16MB left
# Writing new chunk; 6MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct2_v1.ct_rtM.img
# Will write 5.6514528 10MB chunks.
# Writing new chunk; 56MB left
# Writing new chunk; 46MB left
# Writing new chunk; 36MB left
# Writing new chunk; 26MB left
# Writing new chunk; 16MB left
# Writing new chunk; 6MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct2_v1.ct_lbM.img
# Will write 5.6514528 10MB chunks.
# Writing new chunk; 56MB left
# Writing new chunk; 46MB left
# Writing new chunk; 36MB left
# Writing new chunk; 26MB left
# Writing new chunk; 16MB left
# Writing new chunk; 6MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct2_v1.ct_rbM.img
# Will write 5.6514528 10MB chunks.
# Writing new chunk; 56MB left
# Writing new chunk; 46MB left
# Writing new chunk; 36MB left
# Writing new chunk; 26MB left
# Writing new chunk; 16MB left
# Writing new chunk; 6MB left
# File saved.
# min,max,rng -1000.0 -5.0 995.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 568.7000000000116 1568.7000000000116
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 529.0 1529.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 657.7000000000116 1657.7000000000116
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 780.7000000000116 1780.7000000000116
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3464a_ct2_v1.ct_split_qc.png
# test CT image  12
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3464a_ct3_v1.ct.img
# mean:  0.13001632690429688
# areas[8144, 8431, 7968, 9187, 353]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 203.0, h: 200.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct3_v1.ct_ltM.img
# Will write 5.5961822 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct3_v1.ct_rtM.img
# Will write 5.5961822 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct3_v1.ct_lbM.img
# Will write 5.5961822 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464a_ct3_v1.ct_rbM.img
# Will write 5.5961822 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# min,max,rng -1000.0 52.0 1052.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 217.0 1217.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 140.0 1140.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 271.0 1271.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 260.0 1260.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3464a_ct3_v1.ct_split_qc.png
# test CT image  13
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3464b_ct2_v1.ct.img
# mean:  0.1099853515625
# areas[6747, 5364, 7613, 9108]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 190.0, h: 199.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct2_v1.ct_ltM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct2_v1.ct_rtM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct2_v1.ct_lbM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct2_v1.ct_rbM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# min,max,rng -1000.0 -25.0 975.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 481.0 1481.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 301.0199999999895 1301.0199999999895
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 312.0 1312.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 387.0 1387.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3464b_ct2_v1.ct_split_qc.png
# test CT image  14
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3464b_ct3_v1.ct.img
# mean:  0.13242340087890625
# areas[11212, 7018, 7368, 9116]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 201.0, h: 195.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct3_v1.ct_ltM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct3_v1.ct_rtM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct3_v1.ct_lbM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3464b_ct3_v1.ct_rbM.img
# Will write 5.4864558 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# min,max,rng -1000.0 74.0 1074.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 259.0 1259.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 181.0 1181.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 288.0 1288.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 217.0 1217.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3464b_ct3_v1.ct_split_qc.png
# test CT image  15
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3465a_ct1_v1.ct.img
# mean:  0.041416168212890625
# areas[10857]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3465a_ct1_v1.ct_ctrM.img
# Will write 4.0643582 10MB chunks.
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# min,max,rng -1000.0 -27.0 973.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 448.0 1448.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3465a_ct1_v1.ct_split_qc.png
# test CT image  16
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3465b_ct1_v1.ct.img
# mean:  0.05345916748046875
# areas[14014]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3465b_ct1_v1.ct_ctrM.img
# Will write 3.58112 10MB chunks.
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# min,max,rng -1000.0 19.0 1019.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 495.0 1495.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3465b_ct1_v1.ct_split_qc.png
# test CT image  17
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3527a_ct1_v1.ct.img
# mean:  0.044231414794921875
# areas[11595]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3527a_ct1_v1.ct_ctrM.img
# Will write 4.90238 10MB chunks.
# Writing new chunk; 49MB left
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# min,max,rng -999.0 62.0 1061.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 1051.8199999999924 2050.8199999999924
# min_new,max_new 0.0 254.99997
# writing /home/wustl/mmilchenko/temp/mpet3527a_ct1_v1.ct_split_qc.png
# test CT image  18
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3527b_ct1_v1.ct.img
# mean:  0.0443878173828125
# areas[11636]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3527b_ct1_v1.ct_ctrM.img
# Will write 3.2859008 10MB chunks.
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# min,max,rng -999.0 59.0 1058.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 826.0 1825.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3527b_ct1_v1.ct_split_qc.png
# test CT image  19
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3528a_ct1_v1.ct.img
# mean:  0.14208602905273438
# areas[9019, 8464, 9692, 10072]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 198.0, h: 196.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct1_v1.ct_ltM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct1_v1.ct_rtM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct1_v1.ct_rbM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct1_v1.ct_lbM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# min,max,rng -999.0 24.0 1023.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 134.0 1133.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 146.0 1145.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 230.0 1229.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 214.17999999999302 1213.179999999993
# min_new,max_new 0.0 254.99997
# writing /home/wustl/mmilchenko/temp/mpet3528a_ct1_v1.ct_split_qc.png
# test CT image  20
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3528a_ct2_v1.ct.img
# mean:  0.14380264282226562
# areas[8731, 8872, 10338, 9756]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 197.5, h: 202.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct2_v1.ct_rtM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct2_v1.ct_ltM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct2_v1.ct_rbM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528a_ct2_v1.ct_lbM.img
# Will write 5.5411832 10MB chunks.
# Writing new chunk; 55MB left
# Writing new chunk; 45MB left
# Writing new chunk; 35MB left
# Writing new chunk; 25MB left
# Writing new chunk; 15MB left
# Writing new chunk; 5MB left
# File saved.
# min,max,rng -999.0 40.0 1039.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 177.0 1176.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 172.0 1171.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 223.0 1222.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 199.0 1198.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3528a_ct2_v1.ct_split_qc.png
# test CT image  21
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3528b_ct1_v1.ct.img
# mean:  0.12365341186523438
# areas[6373, 7171, 725, 9712, 8434]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 205.0, h: 202.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct1_v1.ct_rtM.img
# Will write 4.16888 10MB chunks.
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct1_v1.ct_ltM.img
# Will write 4.16888 10MB chunks.
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct1_v1.ct_rbM.img
# Will write 4.16888 10MB chunks.
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct1_v1.ct_lbM.img
# Will write 4.16888 10MB chunks.
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# min,max,rng -999.0 56.0 1055.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 77.0 1076.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 81.0 1080.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 99.0 1098.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 44.0 1043.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3528b_ct1_v1.ct_split_qc.png
# test CT image  22
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3528b_ct2_v1.ct.img
# mean:  0.1282196044921875
# areas[6546, 5884, 397, 745, 10828, 9212]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 210.5, h: 197.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct2_v1.ct_rtM.img
# Will write 4.37472 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct2_v1.ct_ltM.img
# Will write 4.37472 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct2_v1.ct_rbM.img
# Will write 4.37472 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3528b_ct2_v1.ct_lbM.img
# Will write 4.37472 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# min,max,rng -999.0 84.0 1083.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 54.0 1053.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 39.0 1038.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 90.0 1089.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 59.0 1058.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3528b_ct2_v1.ct_split_qc.png
# test CT image  23
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3531a_ct1_v1.ct.img
# mean:  0.045135498046875
# areas[11832]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3531a_ct1_v1.ct_ctrM.img
# Will write 4.39992 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# min,max,rng -999.0 126.0 1125.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 929.0 1928.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3531a_ct1_v1.ct_split_qc.png
# test CT image  24
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3531b_ct11_v1.ct.img
# mean:  0.044464111328125
# areas[11656]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3531b_ct11_v1.ct_ctrM.img
# Will write 3.77208 10MB chunks.
# Writing new chunk; 37MB left
# Writing new chunk; 27MB left
# Writing new chunk; 17MB left
# Writing new chunk; 7MB left
# File saved.
# min,max,rng -1000.0 55.0 1055.0
# min_new,max_new 0.0 255.0
# min,max,rng -1000.0 841.0 1841.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3531b_ct11_v1.ct_split_qc.png
# test CT image  25
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3532a_ct1_v1.ct.img
# mean:  0.06476211547851562
# areas[16977]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3532a_ct1_v1.ct_ctrM.img
# Will write 6.277355 10MB chunks.
# Writing new chunk; 62MB left
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# min,max,rng -999.0 128.0 1127.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 556.0 1555.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3532a_ct1_v1.ct_split_qc.png
# test CT image  26
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3532b_ct1_v1.ct.img
# mean:  0.043399810791015625
# areas[11377]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3532b_ct1_v1.ct_ctrM.img
# Will write 3.1784672 10MB chunks.
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# min,max,rng -999.0 53.0 1052.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 920.359999999986 1919.359999999986
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3532b_ct1_v1.ct_split_qc.png
# test CT image  27
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3542a_ct1_v1.ct.img
# mean:  0.13362884521484375
# areas[7995, 7323, 869, 9522, 9321]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 209.5, h: 200.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct1_v1.ct_rtM.img
# Will write 4.37472 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct1_v1.ct_ltM.img
# Will write 4.37472 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct1_v1.ct_rbM.img
# Will write 4.249728 10MB chunks.
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct1_v1.ct_lbM.img
# Will write 4.187232 10MB chunks.
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# min,max,rng -999.0 62.0 1061.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 69.0 1068.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 70.0 1069.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 104.0 1103.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 55.0 1054.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3542a_ct1_v1.ct_split_qc.png
# test CT image  28
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3542a_ct2_v1.ct.img
# mean:  0.147247314453125
# areas[9313, 9340, 9784, 10163]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 190.0, h: 199.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct2_v1.ct_ltM.img
# Will write 3.9284192 10MB chunks.
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct2_v1.ct_rtM.img
# Will write 3.9284192 10MB chunks.
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct2_v1.ct_lbM.img
# Will write 3.9284192 10MB chunks.
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542a_ct2_v1.ct_rbM.img
# Will write 3.9284192 10MB chunks.
# Writing new chunk; 39MB left
# Writing new chunk; 29MB left
# Writing new chunk; 19MB left
# Writing new chunk; 9MB left
# File saved.
# min,max,rng -999.0 46.0 1045.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 110.0 1109.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 123.0 1122.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 111.0 1110.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 143.0 1142.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3542a_ct2_v1.ct_split_qc.png
# test CT image  29
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3542b_ct1_v1.ct.img
# mean:  0.13589859008789062
# areas[8447, 7270, 829, 9610, 9469]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 207.0, h: 204.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct1_v1.ct_rtM.img
# Will write 4.2506208 10MB chunks.
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct1_v1.ct_ltM.img
# Will write 4.2506208 10MB chunks.
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct1_v1.ct_rbM.img
# Will write 4.1684832 10MB chunks.
# Writing new chunk; 41MB left
# Writing new chunk; 31MB left
# Writing new chunk; 21MB left
# Writing new chunk; 11MB left
# Writing new chunk; 1MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct1_v1.ct_lbM.img
# Will write 4.0452768 10MB chunks.
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# min,max,rng -999.0 61.0 1060.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 93.0 1092.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 83.0 1082.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 150.0 1149.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 104.0 1103.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3542b_ct1_v1.ct_split_qc.png
# test CT image  30
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,496,1)
# Reading microPET image data...
# Splitting mpet3542b_ct2_v1.ct.img
# mean:  0.14125442504882812
# areas[7892, 8476, 10829, 9832]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 192.0, h: 203.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct2_v1.ct_rtM.img
# Will write 4.0879328 10MB chunks.
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct2_v1.ct_ltM.img
# Will write 4.0879328 10MB chunks.
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct2_v1.ct_rbM.img
# Will write 4.0879328 10MB chunks.
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3542b_ct2_v1.ct_lbM.img
# Will write 4.0879328 10MB chunks.
# Writing new chunk; 40MB left
# Writing new chunk; 30MB left
# Writing new chunk; 20MB left
# Writing new chunk; 10MB left
# Writing new chunk; 0MB left
# File saved.
# min,max,rng -999.0 67.0 1066.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 79.0 1078.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 66.0 1065.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 114.0 1113.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 73.0 1072.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3542b_ct2_v1.ct_split_qc.png
# test CT image  31
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3552a_ct1_v1.ct.img
# mean:  0.1441802978515625
# areas[8758, 8614, 9510, 10914]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 204.5, h: 204.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3552a_ct1_v1.ct_ltM.img
# Will write 5.6514528 10MB chunks.
# Writing new chunk; 56MB left
# Writing new chunk; 46MB left
# Writing new chunk; 36MB left
# Writing new chunk; 26MB left
# Writing new chunk; 16MB left
# ...
# writing /home/wustl/mmilchenko/temp/mpet3827b_ct1_v1.ct_split_qc.png
# test CT image  110
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3827c_ct1_v1.ct.img
# mean:  0.052829742431640625
# areas[13849]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3827c_ct1_v1.ct_ctrM.img
# Will write 6.277355 10MB chunks.
# Writing new chunk; 62MB left
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# min,max,rng -999.0 99.0 1098.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 412.0 1411.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3827c_ct1_v1.ct_split_qc.png
# test CT image  111
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3833a_ct1_v1.ct.img
# mean:  0.15384292602539062
# areas[9164, 9135, 11329, 10701]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 197.0, h: 197.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833a_ct1_v1.ct_ltM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833a_ct1_v1.ct_rtM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833a_ct1_v1.ct_lbM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833a_ct1_v1.ct_rbM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# min,max,rng -999.0 45.0 1044.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 140.0 1139.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 311.0 1310.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 166.0 1165.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 295.0 1294.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3833a_ct1_v1.ct_split_qc.png
# test CT image  112
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3833b_ct1_v1.ct.img
# mean:  0.14770126342773438
# areas[9108, 9549, 9563, 10499]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 189.0, h: 196.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833b_ct1_v1.ct_ltM.img
# Will write 5.2168928 10MB chunks.
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833b_ct1_v1.ct_rtM.img
# Will write 5.2168928 10MB chunks.
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833b_ct1_v1.ct_rbM.img
# Will write 5.2168928 10MB chunks.
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833b_ct1_v1.ct_lbM.img
# Will write 5.2168928 10MB chunks.
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# min,max,rng -999.0 49.0 1048.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 190.0 1189.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 199.0 1198.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 266.0 1265.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 240.0 1239.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3833b_ct1_v1.ct_split_qc.png
# test CT image  113
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3833c_ct1_v1.ct.img
# mean:  0.156585693359375
# areas[9394, 10201, 10945, 10508]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 191.0, h: 200.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833c_ct1_v1.ct_ltM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833c_ct1_v1.ct_rtM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833c_ct1_v1.ct_lbM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833c_ct1_v1.ct_rbM.img
# Will write 5.432 10MB chunks.
# Writing new chunk; 54MB left
# Writing new chunk; 44MB left
# Writing new chunk; 34MB left
# Writing new chunk; 24MB left
# Writing new chunk; 14MB left
# Writing new chunk; 4MB left
# File saved.
# min,max,rng -999.0 46.139999999984866 1045.1399999999849
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 167.0 1166.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 209.0 1208.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 227.0 1226.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 359.0 1358.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3833c_ct1_v1.ct_split_qc.png
# test CT image  114
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3833d_ct1_v1.ct.img
# mean:  0.04810333251953125
# areas[12610]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3833d_ct1_v1.ct_ctrM.img
# Will write 5.6514528 10MB chunks.
# Writing new chunk; 56MB left
# Writing new chunk; 46MB left
# Writing new chunk; 36MB left
# Writing new chunk; 26MB left
# Writing new chunk; 16MB left
# Writing new chunk; 6MB left
# File saved.
# min,max,rng -999.0 129.0 1128.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 550.0 1549.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3833d_ct1_v1.ct_split_qc.png
# test CT image  115
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3835a_ct1_v1.ct.img
# mean:  0.13540267944335938
# areas[10115, 474, 11814, 13092]
# valid regions detected: 3
# split images (axial projection):
# harmonize_rects, nrect=3, w: 197.0, h: 206.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835a_ct1_v1.ct_ltM.img
# Will write 5.7628088 10MB chunks.
# Writing new chunk; 57MB left
# Writing new chunk; 47MB left
# Writing new chunk; 37MB left
# Writing new chunk; 27MB left
# Writing new chunk; 17MB left
# Writing new chunk; 7MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835a_ct1_v1.ct_rbM.img
# Will write 5.7628088 10MB chunks.
# Writing new chunk; 57MB left
# Writing new chunk; 47MB left
# Writing new chunk; 37MB left
# Writing new chunk; 27MB left
# Writing new chunk; 17MB left
# Writing new chunk; 7MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835a_ct1_v1.ct_lbM.img
# Will write 5.7628088 10MB chunks.
# Writing new chunk; 57MB left
# Writing new chunk; 47MB left
# Writing new chunk; 37MB left
# Writing new chunk; 27MB left
# Writing new chunk; 17MB left
# Writing new chunk; 7MB left
# File saved.
# min,max,rng -999.0 70.0 1069.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 169.0 1168.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 196.0 1195.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 303.0 1302.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3835a_ct1_v1.ct_split_qc.png
# test CT image  116
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3835b_ct1_v1.ct.img
# mean:  0.15822219848632812
# areas[9904, 9747, 11099, 10727]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 199.0, h: 198.5
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835b_ct1_v1.ct_ltM.img
# Will write 5.3778158 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835b_ct1_v1.ct_rtM.img
# Will write 5.3778158 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835b_ct1_v1.ct_lbM.img
# Will write 5.3778158 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835b_ct1_v1.ct_rbM.img
# Will write 5.3778158 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# min,max,rng -999.0 56.0 1055.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 227.60000000000582 1226.6000000000058
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 167.0 1166.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 229.60000000000582 1228.6000000000058
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 291.0 1290.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3835b_ct1_v1.ct_split_qc.png
# test CT image  117
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3835c_ct1_v1.ct.img
# mean:  0.1650848388671875
# areas[10330, 10711, 11001, 11234]
# valid regions detected: 4
# split images (axial projection):
# harmonize_rects, nrect=4, w: 194.0, h: 198.0
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835c_ct1_v1.ct_rtM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835c_ct1_v1.ct_ltM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835c_ct1_v1.ct_rbM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835c_ct1_v1.ct_lbM.img
# Will write 5.3239032 10MB chunks.
# Writing new chunk; 53MB left
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# min,max,rng -999.0 61.0 1060.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 157.0 1156.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 192.17999999999302 1191.179999999993
# min_new,max_new 0.0 254.99997
# min,max,rng -999.0 227.0 1226.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 210.0 1209.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3835c_ct1_v1.ct_split_qc.png
# test CT image  118
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3835d_ct1_v1.ct.img
# mean:  0.04958343505859375
# areas[12998]
# valid regions detected: 1
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3835d_ct1_v1.ct_ctrM.img
# Will write 6.2190968 10MB chunks.
# Writing new chunk; 62MB left
# Writing new chunk; 52MB left
# Writing new chunk; 42MB left
# Writing new chunk; 32MB left
# Writing new chunk; 22MB left
# Writing new chunk; 12MB left
# Writing new chunk; 2MB left
# File saved.
# min,max,rng -999.0 135.0 1134.0
# min_new,max_new 0.0 255.0
# min,max,rng -999.0 583.0 1582.0
# min_new,max_new 0.0 255.0
# writing /home/wustl/mmilchenko/temp/mpet3835d_ct1_v1.ct_split_qc.png
# test CT image  119
# checking if PET modality
# Failed to parse parameters: axial_blocks, axial_crystals_per_block, axial_crystal_pitch, isotope_branching_fraction
# checking if CT modality
# CT  modality detected
# File dimensions: (512,512,679,1)
# Reading microPET image data...
# Splitting mpet3841a_ct1_v1.ct.img
# mean:  0.08800506591796875
# areas[11121, 11949]
# valid regions detected: 2
# split images (axial projection):
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3841a_ct1_v1.ct_lM.img
# Will write 4.39992 10MB chunks.
# Writing new chunk; 43MB left
# Writing new chunk; 33MB left
# Writing new chunk; 23MB left
# Writing new chunk; 13MB left
# Writing new chunk; 3MB left
# File saved.
# Saving files...
# writing microPET image to  /home/wustl/mmilchenko/temp/mpet3841a_ct1_v1.ct_rM.img
# Will write 4.39992 10MB chunks.
# Writing new chunk; 43MB left

# %%
for i in range(0,1):#len(images_test)):
    print('test PET image ',str(i))
    s=SoM(images_test[i])
    if s.pi is None:
        print( images_test[i], ': unknown image modality' )
        continue
    s.split_mice_pet('/home/wustl/mmilchenko/temp1',save_analyze=True,output_qc=True)

# %%
d={'l':'l','r':'r','ctr':'ctr','lb':'lb','rb':'rb','lt':'lt','rt':'rt'}
sm="l:r,r:l,ctr:c,lt:rb,rt:lb,lb:rt,rb:lt"
for s in sm.split(','): 
    mp=s.split(':')
    if len(mp)<2: continue
    if mp[0] in d.keys(): d[mp[0]]=mp[1]
print(d)
# Out:
# {'l': 'r', 'r': 'l', 'ctr': 'c', 'lb': 'rt', 'rb': 'lt', 'lt': 'rb', 'rt': 'lb'}
